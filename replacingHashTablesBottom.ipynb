# %%
import pandas as pd
import numpy as np
import seaborn as sns  
import matplotlib.pyplot as plt
from datetime import date
from dateutil.relativedelta import relativedelta
# %matplotlib inline 

# IMPORTANT:
# Redownload the files from slack and Outlook

# %% [markdown]
# ##### DATA (the anonymised dataframe)

# %%
#import main dataframe
data = pd.read_csv('locations.csv', low_memory=False)

# %%
#rename City column and drop empty columns
data.rename( columns={'Unnamed: 5':'City'}, inplace=True )
data = data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1)

# %%
#drop VisitorID and ContentInfo
data = data.drop(columns=['VisitorID', 'ContentInfo'])

# %%
#just getting rid of the space after the name
data = data.replace('STH Ayshire St Leonards ', 'STH Ayshire St Leonards')
data.head()
# Out:
#                Time  ExternalID  Role                    Building      City  \
# 0  29/10/2018 10:55      5325.0  User                Broom Ground  Stirling
# 1  29/10/2018 10:50      5325.0  User                Broom Ground  Stirling
# 2  29/10/2018 10:49      5325.0  User                Broom Ground  Stirling
# 3  29/10/2018 10:49      5325.0  User                Broom Ground  Stirling
# 4  29/10/2018 10:48         NaN  User  Belses Gardens - Care Home   Glasgow
#
#        LinkTitle  LinkType
# 0      Sam Smith  Internet
# 1     Elton John  Internet
# 2       My Music  Category
# 3  Entertainment  Category
# 4  BBC Formula 1  Internet

# %%
#drop nan values in Building
data = data.dropna(subset=['Building'])
data.head()
# Out:
#                Time  ExternalID  Role                    Building      City  \
# 0  29/10/2018 10:55      5325.0  User                Broom Ground  Stirling
# 1  29/10/2018 10:50      5325.0  User                Broom Ground  Stirling
# 2  29/10/2018 10:49      5325.0  User                Broom Ground  Stirling
# 3  29/10/2018 10:49      5325.0  User                Broom Ground  Stirling
# 4  29/10/2018 10:48         NaN  User  Belses Gardens - Care Home   Glasgow
#
#        LinkTitle  LinkType
# 0      Sam Smith  Internet
# 1     Elton John  Internet
# 2       My Music  Category
# 3  Entertainment  Category
# 4  BBC Formula 1  Internet

# %%
#change time to datetime
data['Time'] = pd.to_datetime(data['Time'], format = "%d/%m/%Y %H:%M", utc=False)
data.head()
# Out:
#                  Time  ExternalID  Role                    Building      City  \
# 0 2018-10-29 10:55:00      5325.0  User                Broom Ground  Stirling
# 1 2018-10-29 10:50:00      5325.0  User                Broom Ground  Stirling
# 2 2018-10-29 10:49:00      5325.0  User                Broom Ground  Stirling
# 3 2018-10-29 10:49:00      5325.0  User                Broom Ground  Stirling
# 4 2018-10-29 10:48:00         NaN  User  Belses Gardens - Care Home   Glasgow
#
#        LinkTitle  LinkType
# 0      Sam Smith  Internet
# 1     Elton John  Internet
# 2       My Music  Category
# 3  Entertainment  Category
# 4  BBC Formula 1  Internet

# %%
#change ExternalIDs to integers
data.ExternalID = data.ExternalID.fillna(0).astype(int)

# %%
#drop rows that are identical
data = data.drop_duplicates(keep='first')

# %%
#new dataframe with no null ExternalID vaues
data = data[data.ExternalID != 0]

# %% [markdown]
# ##### USERS (the user dataframe)

# %%
#import users dataframe
users = pd.read_csv('PrimaryConditions age sex by customer reference.csv', low_memory=False)

# %%
#drop empty column and CleverCogsUserId
users = users.drop(users.columns[users.columns.str.contains('unnamed',case = False)],axis = 1)
users = users.drop(columns=['CleverCogsUserId'])

# %%
#delete empty row
users = users.dropna(axis=0, how='all', inplace=False)

# %%
#change ExternalID into integers
users['ExternalID'] = users['ExternalID'].apply(np.int64)
users.shape
users.head()
# Out:
#    ExternalID   BirthDate Gender     Condition
# 0        4703  04/07/1965      F  Spina Bifida
# 1        4704  21/06/1940      F          COPD
# 2        4706  25/02/1931      F      Dementia
# 3        4707  18/09/1982      F  Brain Injury
# 4        4708  20/12/1931      F           NaN

# %%
#drop duplicates
users = users.drop_duplicates(subset = ['ExternalID'], keep='last')
users.shape
# Out:
# (680, 4)

# %%
#change BirthDate to date time
#users['BirthDate'] = pd.to_datetime(users['BirthDate'], format = "%m/%d/%y", dayfirst=False, utc=True)

users['BirthDate'] = pd.to_datetime(users['BirthDate'], errors='coerce', dayfirst=False, yearfirst=False, 
                   format="%d/%m/%Y", utc=False, infer_datetime_format=False, origin='unix')
users = users.set_index(pd.DatetimeIndex(users['BirthDate']))

#Remove erroneous entries
threshold = pd.to_datetime("2010-01-01", format="%Y-%m-%d", utc=False, origin='unix')
users = users[users['BirthDate'] < threshold]

users.head()
# Out:
#             ExternalID  BirthDate Gender     Condition
# BirthDate
# 1965-07-04        4703 1965-07-04      F  Spina Bifida
# 1940-06-21        4704 1940-06-21      F          COPD
# 1931-02-25        4706 1931-02-25      F      Dementia
# 1982-09-18        4707 1982-09-18      F  Brain Injury
# 1931-12-20        4708 1931-12-20      F           NaN

# %%
now = pd.to_datetime(date.today())

def getYears(start):
    diff = relativedelta(now, start)
    return diff.years

# Add a new column that contains the age of the user
users["Age"] = users['BirthDate'].map(getYears)

# %%
users.head()
# Out:
#             ExternalID  BirthDate Gender     Condition  Age
# BirthDate
# 1965-07-04        4703 1965-07-04      F  Spina Bifida   53
# 1940-06-21        4704 1940-06-21      F          COPD   78
# 1931-02-25        4706 1931-02-25      F      Dementia   87
# 1982-09-18        4707 1982-09-18      F  Brain Injury   36
# 1931-12-20        4708 1931-12-20      F           NaN   86

# %%
users.shape
# Out:
# (672, 5)

# %%
#print all Cities, drop or group unneccessary
city = data.City.unique()
index = 1
for item in city:
    print(index, ': ', item)
    index += 1
# Out:
# 1 :  Stirling
# 2 :  Ayr
# 3 :  Edinburgh
# 4 :  Dundee
# 5 :  Aberdeen
# 6 :  Dundee (Tayside)
# 7 :  test user
# 8 :  Glasgow
# 9 :  Arbroath (Tayside)

# %%
data = data.replace('Dundee (Tayside)', 'Dundee')

# %%
#count null values for City
sum(pd.isnull(data['City']))
# Out:
# 0

# %%
location = data.Building.unique()
index = 1
for item in location:
    print(index, ': ', item)
    index += 1
# Out:
# 1 :  Broom Ground
# 2 :  STH Ayshire St Leonards
# 3 :  Edinburgh West C@H
# 4 :  Broom Middle
# 5 :  Broom Supported Flats
# 6 :  Charleston
# 7 :  Aberdeen Raeden Court CH
# 8 :  LFC Main Building
# 9 :  Edinburgh Responder Service
# 10 :  Edinburgh
# 11 :  Complex Home 1
# 12 :  Edinburgh East C@H
# 13 :  Belses Gardens - Care Home
# 14 :  Glasgow C@H
# 15 :  Broom Houses
# 16 :  Aberdeen C@H
# 17 :  LFC Care at Home
# 18 :  Dundee
# 19 :  Arbroath

# %%
#see if they have locations so I can assign the city

pairLocation = {}
for index, row in (data.dropna()).iterrows():
    if row.Building in pairLocation:
        continue
    else:
        pairLocation[row.Building] = row.City

# %%
for index, row in data.iterrows():
    if row.City is None:
        if row.Building in pairLocation:
            # replace row with this row
            row.City = pairLocaton[row.Building]
        else: 
            continue      
    else: 
        continue

# %%
data
# Out:
#                       Time  ExternalID  Role                    Building  \
# 0      2018-10-29 10:55:00        5325  User                Broom Ground
# 1      2018-10-29 10:50:00        5325  User                Broom Ground
# 2      2018-10-29 10:49:00        5325  User                Broom Ground
# 3      2018-10-29 10:49:00        5325  User                Broom Ground
# 5      2018-10-29 10:41:00        5541  User     STH Ayshire St Leonards
# 6      2018-10-29 10:39:00        5541  User     STH Ayshire St Leonards
# 7      2018-10-29 10:38:00        5541  User     STH Ayshire St Leonards
# 15     2018-10-29 10:33:00        5541  User     STH Ayshire St Leonards
# 21     2018-10-29 10:12:00        5207  User          Edinburgh West C@H
# 22     2018-10-29 10:12:00        5207  User          Edinburgh West C@H
# 23     2018-10-29 10:12:00        5207  User          Edinburgh West C@H
# 24     2018-10-29 10:12:00        5207  User          Edinburgh West C@H
# 27     2018-10-29 10:00:00        5541  User     STH Ayshire St Leonards
# 28     2018-10-29 10:00:00        5541  User     STH Ayshire St Leonards
# 29     2018-10-29 10:00:00        5541  User     STH Ayshire St Leonards
# 30     2018-10-29 09:59:00        5541  User     STH Ayshire St Leonards
# 31     2018-10-29 09:55:00        5207  User          Edinburgh West C@H
# 33     2018-10-29 09:52:00        5207  User          Edinburgh West C@H
# 38     2018-10-29 09:44:00        5207  User          Edinburgh West C@H
# 39     2018-10-29 09:44:00        5207  User          Edinburgh West C@H
# 40     2018-10-29 09:44:00        5207  User          Edinburgh West C@H
# 41     2018-10-29 09:44:00        5207  User          Edinburgh West C@H
# 50     2018-10-29 08:51:00        5306  User                Broom Middle
# 51     2018-10-29 08:51:00        5306  User                Broom Middle
# 52     2018-10-29 08:51:00        5306  User                Broom Middle
# 53     2018-10-29 08:51:00        5306  User                Broom Middle
# 55     2018-10-29 08:25:00        5207  User          Edinburgh West C@H
# 56     2018-10-29 08:25:00        5207  User          Edinburgh West C@H
# 57     2018-10-29 08:25:00        5207  User          Edinburgh West C@H
# 58     2018-10-29 08:25:00        5207  User          Edinburgh West C@H
# ...                    ...         ...   ...                         ...
# 132362 2018-01-01 06:24:00        5055  User                  Charleston
# 132363 2018-01-01 06:20:00        5055  User                  Charleston
# 132364 2018-01-01 06:04:00        5055  User                  Charleston
# 132365 2018-01-01 06:04:00        5055  User                  Charleston
# 132374 2018-01-01 03:14:00        5207  User          Edinburgh West C@H
# 132375 2018-01-01 03:14:00        5207  User          Edinburgh West C@H
# 132376 2018-01-01 03:14:00        5207  User          Edinburgh West C@H
# 132377 2018-01-01 03:14:00        5207  User          Edinburgh West C@H
# 132378 2018-01-01 03:09:00        5207  User          Edinburgh West C@H
# 132379 2018-01-01 03:09:00        5207  User          Edinburgh West C@H
# 132380 2018-01-01 02:34:00        5541  User     STH Ayshire St Leonards
# 132381 2018-01-01 02:33:00        5541  User     STH Ayshire St Leonards
# 132382 2018-01-01 02:33:00        5541  User     STH Ayshire St Leonards
# 132407 2018-01-01 01:34:00        5055  User                  Charleston
# 132408 2018-01-01 01:30:00        5055  User                  Charleston
# 132409 2018-01-01 01:30:00        5055  User                  Charleston
# 132416 2018-01-01 01:24:00        7809  User  Belses Gardens - Care Home
# 132417 2018-01-01 01:24:00        7809  User  Belses Gardens - Care Home
# 132423 2018-01-01 01:20:00        7809  User  Belses Gardens - Care Home
# 132424 2018-01-01 01:20:00        7809  User  Belses Gardens - Care Home
# 132425 2018-01-01 01:20:00        7809  User  Belses Gardens - Care Home
# 132426 2018-01-01 01:18:00        5977  User       Broom Supported Flats
# 132427 2018-01-01 01:18:00        5977  User       Broom Supported Flats
# 132428 2018-01-01 01:18:00        5977  User       Broom Supported Flats
# 132429 2018-01-01 01:18:00        5977  User       Broom Supported Flats
# 132459 2018-01-01 00:46:00        5055  User                  Charleston
# 132460 2018-01-01 00:46:00        5055  User                  Charleston
# 132461 2018-01-01 00:29:00        5055  User                  Charleston
# 132462 2018-01-01 00:20:00        5055  User                  Charleston
# 132463 2018-01-01 00:20:00        5055  User                  Charleston
#
#              City            LinkTitle   LinkType
# 0        Stirling            Sam Smith   Internet
# 1        Stirling           Elton John   Internet
# 2        Stirling             My Music   Category
# 3        Stirling        Entertainment   Category
# 5             Ayr              YouTube   Internet
# 6             Ayr              YouTube   Internet
# 7             Ayr              YouTube   Internet
# 15            Ayr              YouTube   Internet
# 21      Edinburgh     Candy Crush Soda   Internet
# 22      Edinburgh  Single Player Games   Category
# 23      Edinburgh           Play Games   Category
# 24      Edinburgh        Entertainment   Category
# 27            Ayr              YouTube   Internet
# 28            Ayr               Videos   Category
# 29            Ayr        Entertainment   Category
# 30            Ayr          Information   Category
# 31      Edinburgh             Patience  HTML page
# 33      Edinburgh             Patience  HTML page
# 38      Edinburgh     Candy Crush Soda   Internet
# 39      Edinburgh  Single Player Games   Category
# 40      Edinburgh           Play Games   Category
# 41      Edinburgh        Entertainment   Category
# 50       Stirling         Smooth Radio      Radio
# 51       Stirling       Radio Stations   Category
# 52       Stirling        Entertainment   Category
# 53       Stirling             My Music   Category
# 55      Edinburgh     Candy Crush Soda   Internet
# 56      Edinburgh  Single Player Games   Category
# 57      Edinburgh           Play Games   Category
# 58      Edinburgh        Entertainment   Category
# ...           ...                  ...        ...
# 132362     Dundee         My Interests   Category
# 132363     Dundee             Facebook   Internet
# 132364     Dundee             Facebook   Internet
# 132365     Dundee         My Interests   Category
# 132374  Edinburgh             Patience  HTML page
# 132375  Edinburgh  Single Player Games   Category
# 132376  Edinburgh           Play Games   Category
# 132377  Edinburgh        Entertainment   Category
# 132378  Edinburgh         BBC Football   Internet
# 132379  Edinburgh         My Interests   Category
# 132380        Ayr        ITV Test Card   Internet
# 132381        Ayr           Test Cards   Category
# 132382        Ayr        Entertainment   Category
# 132407     Dundee             Facebook   Internet
# 132408     Dundee             Facebook   Internet
# 132409     Dundee         My Interests   Category
# 132416    Glasgow             My Music   Category
# 132417    Glasgow        Entertainment   Category
# 132423    Glasgow         Smooth Radio      Radio
# 132424    Glasgow       Radio Stations   Category
# 132425    Glasgow        Entertainment   Category
# 132426   Stirling             Patience  HTML page
# 132427   Stirling  Single Player Games   Category
# 132428   Stirling           Play Games   Category
# 132429   Stirling        Entertainment   Category
# 132459     Dundee             Facebook   Internet
# 132460     Dundee         My Interests   Category
# 132461     Dundee             Facebook   Internet
# 132462     Dundee             Facebook   Internet
# 132463     Dundee         My Interests   Category
#
# [88073 rows x 7 columns]
